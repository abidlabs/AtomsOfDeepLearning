# %% [markdown]
# # Which Machine Learning Classifier Is the Best on 18 UCI Datasets?

# %% [markdown]
# We all know that deep neural networks (DNNs) are great for image recognition and speech processing. What about good ol' numerical datasets? I compared DNNs to other standard ML algorithms on many public _classification_ datasets from the UCI ML repository, and here are the results. I divided each dataset into a training and test set (80-20 split), and report test accuracies (averaged over 3 random test-train splits) below. The specific classifiers that I tried were:
#
# * Support Vector
# * Naive Bayes
# * Decision Tree
# * Random Forests
# * 1-layer NN with 100 hidden units
# * 2-layer NN with 100 hidden units in each layer
# * 3-layer NN with 100 hidden units in each layer
#
# All techniques use the standard implementations in the `sklearn` library, and did not do any hyper-parameter tuning. The goal was to see which model is best if you want good off-the-shelf performance. A short description of each dataset (taken from the UCI website) is included. Conclusions are listed at the end.

# %%
import pandas as pd, numpy as np
from utils import Timer
from uci_utils import *

# %load_ext autoreload
# %autoreload 2

timer = Timer()
pd.set_option('precision', 3)

# %% [markdown]
# ### Adult Income
# Predict whether income exceeds $50K/yr based on census data.

# %%
timer.start()
X, y = UCI_Dataset_Loader.adult()
scores = compute_test_accuracies(X,y)
timer.end_and_md_print()
print_best(scores)
pd.DataFrame(scores, columns=names, index=['Test Accuracy']).style.apply(highlight_max,axis=1)
# Out:
# Training set size: (26048, 108), Test set size: (6513, 108), \# of classes: 2
# Time needed to run experiment: 1630.932 s
# Best classifier: **Random Forests**
#         <style  type="text/css" >
#
#
#             #T_920cb7e2_3964_11e8_ae4d_985fd3c9006drow0_col3 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#         </style>
#
#         <table id="T_920cb7e2_3964_11e8_ae4d_985fd3c9006d" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Support Vector
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Naive Bayes
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Decision Tree
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Random Forests
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   1-layer NN
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   2-layer NN
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   3-layer NN
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_920cb7e2_3964_11e8_ae4d_985fd3c9006d"
#                  class="row_heading level0 row0" rowspan=1>
#                     Test Accuracy
#
#
#
#                 <td id="T_920cb7e2_3964_11e8_ae4d_985fd3c9006drow0_col0"
#                  class="data row0 col0" >
#                     0.753
#
#
#
#                 <td id="T_920cb7e2_3964_11e8_ae4d_985fd3c9006drow0_col1"
#                  class="data row0 col1" >
#                     0.799
#
#
#
#                 <td id="T_920cb7e2_3964_11e8_ae4d_985fd3c9006drow0_col2"
#                  class="data row0 col2" >
#                     0.817
#
#
#
#                 <td id="T_920cb7e2_3964_11e8_ae4d_985fd3c9006drow0_col3"
#                  class="data row0 col3" >
#                     0.847
#
#
#
#                 <td id="T_920cb7e2_3964_11e8_ae4d_985fd3c9006drow0_col4"
#                  class="data row0 col4" >
#                     0.605
#
#
#
#                 <td id="T_920cb7e2_3964_11e8_ae4d_985fd3c9006drow0_col5"
#                  class="data row0 col5" >
#                     0.599
#
#
#
#                 <td id="T_920cb7e2_3964_11e8_ae4d_985fd3c9006drow0_col6"
#                  class="data row0 col6" >
#                     0.784
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ### Car Evaluation

# %% [markdown]
# The database evaluates cars according to the following concepts: car acceptability, overall price, buying price, price of the maintenance, number of doors, capacity in terms of persons to carry, the size of luggage boot, and estimated safety of the car.

# %%
timer.start()
X, y = UCI_Dataset_Loader.car()
scores = compute_test_accuracies(X,y, verbose=1)
timer.end_and_md_print()
print_best(scores)
pd.DataFrame(scores, columns=names, index=['Test Accuracy']).style.apply(highlight_max,axis=1)
# Out:
# Training set size: (1382, 21), Test set size: (346, 21), \# of classes: 4
# Time needed to run experiment: 12.962 s
# Best classifier: **2-layer NN**
#         <style  type="text/css" >
#
#
#             #T_99dcdd10_3964_11e8_a84f_985fd3c9006drow0_col5 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#         </style>
#
#         <table id="T_99dcdd10_3964_11e8_a84f_985fd3c9006d" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Support Vector
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Naive Bayes
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Decision Tree
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Random Forests
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   1-layer NN
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   2-layer NN
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   3-layer NN
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_99dcdd10_3964_11e8_a84f_985fd3c9006d"
#                  class="row_heading level0 row0" rowspan=1>
#                     Test Accuracy
#
#
#
#                 <td id="T_99dcdd10_3964_11e8_a84f_985fd3c9006drow0_col0"
#                  class="data row0 col0" >
#                     0.906
#
#
#
#                 <td id="T_99dcdd10_3964_11e8_a84f_985fd3c9006drow0_col1"
#                  class="data row0 col1" >
#                     0.799
#
#
#
#                 <td id="T_99dcdd10_3964_11e8_a84f_985fd3c9006drow0_col2"
#                  class="data row0 col2" >
#                     0.962
#
#
#
#                 <td id="T_99dcdd10_3964_11e8_a84f_985fd3c9006drow0_col3"
#                  class="data row0 col3" >
#                     0.935
#
#
#
#                 <td id="T_99dcdd10_3964_11e8_a84f_985fd3c9006drow0_col4"
#                  class="data row0 col4" >
#                     0.993
#
#
#
#                 <td id="T_99dcdd10_3964_11e8_a84f_985fd3c9006drow0_col5"
#                  class="data row0 col5" >
#                     0.999
#
#
#
#                 <td id="T_99dcdd10_3964_11e8_a84f_985fd3c9006drow0_col6"
#                  class="data row0 col6" >
#                     0.997
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ### Credit Default

# %% [markdown]
# This research aimed at the case of customers' default payments in Taiwan and compares the predictive accuracy of probability of default among six data mining methods.

# %%
timer.start()
X, y = UCI_Dataset_Loader.credit_default()
scores = compute_test_accuracies(X,y, verbose=1)
timer.end_and_md_print()
print_best(scores)
pd.DataFrame(scores, columns=names, index=['Test Accuracy']).style.apply(highlight_max,axis=1)
# Out:
# Training set size: (24000, 24), Test set size: (6000, 24), \# of classes: 2
# Time needed to run experiment: 697.384 s
# Best classifier: **Random Forests**
#         <style  type="text/css" >
#
#
#             #T_39a121d2_3966_11e8_ba30_985fd3c9006drow0_col3 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#         </style>
#
#         <table id="T_39a121d2_3966_11e8_ba30_985fd3c9006d" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Support Vector
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Naive Bayes
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Decision Tree
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Random Forests
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   1-layer NN
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   2-layer NN
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   3-layer NN
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_39a121d2_3966_11e8_ba30_985fd3c9006d"
#                  class="row_heading level0 row0" rowspan=1>
#                     Test Accuracy
#
#
#
#                 <td id="T_39a121d2_3966_11e8_ba30_985fd3c9006drow0_col0"
#                  class="data row0 col0" >
#                     0.774
#
#
#
#                 <td id="T_39a121d2_3966_11e8_ba30_985fd3c9006drow0_col1"
#                  class="data row0 col1" >
#                     0.372
#
#
#
#                 <td id="T_39a121d2_3966_11e8_ba30_985fd3c9006drow0_col2"
#                  class="data row0 col2" >
#                     0.723
#
#
#
#                 <td id="T_39a121d2_3966_11e8_ba30_985fd3c9006drow0_col3"
#                  class="data row0 col3" >
#                     0.804
#
#
#
#                 <td id="T_39a121d2_3966_11e8_ba30_985fd3c9006drow0_col4"
#                  class="data row0 col4" >
#                     0.664
#
#
#
#                 <td id="T_39a121d2_3966_11e8_ba30_985fd3c9006drow0_col5"
#                  class="data row0 col5" >
#                     0.662
#
#
#
#                 <td id="T_39a121d2_3966_11e8_ba30_985fd3c9006drow0_col6"
#                  class="data row0 col6" >
#                     0.714
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ### Dermatology

# %% [markdown]
# The differential diagnosis of erythemato-squamous diseases is a real problem in dermatology. They all share the clinical features of erythema and scaling, with very little differences. TPatients were first evaluated clinically with 12 features. Afterwards, skin samples were taken for the evaluation of 22 histopathological features. The values of the histopathological features are determined by an analysis of the samples under a microscope.

# %%
timer.start()
X, y = UCI_Dataset_Loader.dermatology() # <-- change this line for different experiments
scores = compute_test_accuracies(X,y, verbose=1)
timer.end_and_md_print()
print_best(scores)
pd.DataFrame(scores, columns=names, index=['Test Accuracy']).style.apply(highlight_max,axis=1)
# Out:
# Training set size: (292, 94), Test set size: (74, 94), \# of classes: 4
# Time needed to run experiment: 8.086 s
# Best classifier: **Support Vector**
#         <style  type="text/css" >
#
#
#             #T_3e88d318_3966_11e8_a7bd_985fd3c9006drow0_col0 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#         </style>
#
#         <table id="T_3e88d318_3966_11e8_a7bd_985fd3c9006d" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Support Vector
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Naive Bayes
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Decision Tree
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Random Forests
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   1-layer NN
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   2-layer NN
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   3-layer NN
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_3e88d318_3966_11e8_a7bd_985fd3c9006d"
#                  class="row_heading level0 row0" rowspan=1>
#                     Test Accuracy
#
#
#
#                 <td id="T_3e88d318_3966_11e8_a7bd_985fd3c9006drow0_col0"
#                  class="data row0 col0" >
#                     0.622
#
#
#
#                 <td id="T_3e88d318_3966_11e8_a7bd_985fd3c9006drow0_col1"
#                  class="data row0 col1" >
#                     0.189
#
#
#
#                 <td id="T_3e88d318_3966_11e8_a7bd_985fd3c9006drow0_col2"
#                  class="data row0 col2" >
#                     0.559
#
#
#
#                 <td id="T_3e88d318_3966_11e8_a7bd_985fd3c9006drow0_col3"
#                  class="data row0 col3" >
#                     0.527
#
#
#
#                 <td id="T_3e88d318_3966_11e8_a7bd_985fd3c9006drow0_col4"
#                  class="data row0 col4" >
#                     0.482
#
#
#
#                 <td id="T_3e88d318_3966_11e8_a7bd_985fd3c9006drow0_col5"
#                  class="data row0 col5" >
#                     0.486
#
#
#
#                 <td id="T_3e88d318_3966_11e8_a7bd_985fd3c9006drow0_col6"
#                  class="data row0 col6" >
#                     0.491
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ### Diabetic Retinopathy

# %% [markdown]
# This dataset contains features extracted from the Messidor image set to predict whether an image contains signs of diabetic retinopathy or not. All features represent either a detected lesion, a descriptive feature of a anatomical part or an image-level descriptor.

# %%
timer.start()
X, y = UCI_Dataset_Loader.diabetic_retinopathy() # <-- change this line for different experiments
scores = compute_test_accuracies(X,y, verbose=1)
timer.end_and_md_print()
print_best(scores)
pd.DataFrame(scores, columns=names, index=['Test Accuracy']).style.apply(highlight_max,axis=1)
# Out:
# Training set size: (920, 19), Test set size: (231, 19), \# of classes: 2
# Time needed to run experiment: 3.1 s
# Best classifier: **1-layer NN**
#         <style  type="text/css" >
#
#
#             #T_4079042e_3966_11e8_8217_985fd3c9006drow0_col4 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#         </style>
#
#         <table id="T_4079042e_3966_11e8_8217_985fd3c9006d" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Support Vector
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Naive Bayes
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Decision Tree
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Random Forests
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   1-layer NN
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   2-layer NN
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   3-layer NN
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_4079042e_3966_11e8_8217_985fd3c9006d"
#                  class="row_heading level0 row0" rowspan=1>
#                     Test Accuracy
#
#
#
#                 <td id="T_4079042e_3966_11e8_8217_985fd3c9006drow0_col0"
#                  class="data row0 col0" >
#                     0.561
#
#
#
#                 <td id="T_4079042e_3966_11e8_8217_985fd3c9006drow0_col1"
#                  class="data row0 col1" >
#                     0.613
#
#
#
#                 <td id="T_4079042e_3966_11e8_8217_985fd3c9006drow0_col2"
#                  class="data row0 col2" >
#                     0.625
#
#
#
#                 <td id="T_4079042e_3966_11e8_8217_985fd3c9006drow0_col3"
#                  class="data row0 col3" >
#                     0.635
#
#
#
#                 <td id="T_4079042e_3966_11e8_8217_985fd3c9006drow0_col4"
#                  class="data row0 col4" >
#                     0.723
#
#
#
#                 <td id="T_4079042e_3966_11e8_8217_985fd3c9006drow0_col5"
#                  class="data row0 col5" >
#                     0.701
#
#
#
#                 <td id="T_4079042e_3966_11e8_8217_985fd3c9006drow0_col6"
#                  class="data row0 col6" >
#                     0.683
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ### E. coli

# %% [markdown]
# Predict which kind of E. coli you have based on a number of cellular features.

# %%
timer.start()
X, y = UCI_Dataset_Loader.ecoli() # <-- change this line for different experiments
scores = compute_test_accuracies(X,y, verbose=1)
timer.end_and_md_print()
print_best(scores)
pd.DataFrame(scores, columns=names, index=['Test Accuracy']).style.apply(highlight_max,axis=1)
# Out:
# Training set size: (268, 7), Test set size: (68, 7), \# of classes: 8
# Time needed to run experiment: 4.664 s
# Best classifier: **3-layer NN**
#         <style  type="text/css" >
#
#
#             #T_43597922_3966_11e8_84b5_985fd3c9006drow0_col6 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#         </style>
#
#         <table id="T_43597922_3966_11e8_84b5_985fd3c9006d" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Support Vector
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Naive Bayes
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Decision Tree
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Random Forests
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   1-layer NN
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   2-layer NN
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   3-layer NN
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_43597922_3966_11e8_84b5_985fd3c9006d"
#                  class="row_heading level0 row0" rowspan=1>
#                     Test Accuracy
#
#
#
#                 <td id="T_43597922_3966_11e8_84b5_985fd3c9006drow0_col0"
#                  class="data row0 col0" >
#                     0.721
#
#
#
#                 <td id="T_43597922_3966_11e8_84b5_985fd3c9006drow0_col1"
#                  class="data row0 col1" >
#                     0.76
#
#
#
#                 <td id="T_43597922_3966_11e8_84b5_985fd3c9006drow0_col2"
#                  class="data row0 col2" >
#                     0.814
#
#
#
#                 <td id="T_43597922_3966_11e8_84b5_985fd3c9006drow0_col3"
#                  class="data row0 col3" >
#                     0.843
#
#
#
#                 <td id="T_43597922_3966_11e8_84b5_985fd3c9006drow0_col4"
#                  class="data row0 col4" >
#                     0.76
#
#
#
#                 <td id="T_43597922_3966_11e8_84b5_985fd3c9006drow0_col5"
#                  class="data row0 col5" >
#                     0.907
#
#
#
#                 <td id="T_43597922_3966_11e8_84b5_985fd3c9006drow0_col6"
#                  class="data row0 col6" >
#                     0.912
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ### EEG to Predict Eye State

# %% [markdown]
# All data is from one continuous EEG measurement with the Emotiv EEG Neuroheadset. The duration of the measurement was 117 seconds. The eye state was detected via a camera during the EEG measurement and added later manually to the file after analysing the video frames. '1' indicates the eye-closed and '0' the eye-open state. All values are in chronological order with the first measured value at the top of the data.

# %%
timer.start()
X, y = UCI_Dataset_Loader.eeg_eyes() # <-- change this line for different experiments
scores = compute_test_accuracies(X,y, verbose=1)
timer.end_and_md_print()
print_best(scores)
pd.DataFrame(scores, columns=names, index=['Test Accuracy']).style.apply(highlight_max,axis=1)
# Out:
# Training set size: (11984, 14), Test set size: (2996, 14), \# of classes: 2
# Time needed to run experiment: 89.296 s
# Best classifier: **Random Forests**
#         <style  type="text/css" >
#
#
#             #T_78b03dec_3966_11e8_8875_985fd3c9006drow0_col3 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#         </style>
#
#         <table id="T_78b03dec_3966_11e8_8875_985fd3c9006d" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Support Vector
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Naive Bayes
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Decision Tree
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Random Forests
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   1-layer NN
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   2-layer NN
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   3-layer NN
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_78b03dec_3966_11e8_8875_985fd3c9006d"
#                  class="row_heading level0 row0" rowspan=1>
#                     Test Accuracy
#
#
#
#                 <td id="T_78b03dec_3966_11e8_8875_985fd3c9006drow0_col0"
#                  class="data row0 col0" >
#                     0.561
#
#
#
#                 <td id="T_78b03dec_3966_11e8_8875_985fd3c9006drow0_col1"
#                  class="data row0 col1" >
#                     0.486
#
#
#
#                 <td id="T_78b03dec_3966_11e8_8875_985fd3c9006drow0_col2"
#                  class="data row0 col2" >
#                     0.832
#
#
#
#                 <td id="T_78b03dec_3966_11e8_8875_985fd3c9006drow0_col3"
#                  class="data row0 col3" >
#                     0.898
#
#
#
#                 <td id="T_78b03dec_3966_11e8_8875_985fd3c9006drow0_col4"
#                  class="data row0 col4" >
#                     0.504
#
#
#
#                 <td id="T_78b03dec_3966_11e8_8875_985fd3c9006drow0_col5"
#                  class="data row0 col5" >
#                     0.445
#
#
#
#                 <td id="T_78b03dec_3966_11e8_8875_985fd3c9006drow0_col6"
#                  class="data row0 col6" >
#                     0.491
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ### Haberman's Breast Cancer Survival

# %% [markdown]
# The dataset contains cases from a study that was conducted between 1958 and 1970 at the University of Chicago's Billings Hospital on the survival of patients who had undergone surgery for breast cancer.

# %%
timer.start()
X, y = UCI_Dataset_Loader.haberman() # <-- change this line for different experiments
scores = compute_test_accuracies(X,y, verbose=1)
timer.end_and_md_print()
print_best(scores)
pd.DataFrame(scores, columns=names, index=['Test Accuracy']).style.apply(highlight_max,axis=1)
# Out:
# Training set size: (244, 3), Test set size: (62, 3), \# of classes: 2
# Time needed to run experiment: 0.577 s
# Best classifier: **Naive Bayes, 2-layer NN**
#         <style  type="text/css" >
#
#
#             #T_79219a92_3966_11e8_a752_985fd3c9006drow0_col1 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_79219a92_3966_11e8_a752_985fd3c9006drow0_col5 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#         </style>
#
#         <table id="T_79219a92_3966_11e8_a752_985fd3c9006d" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Support Vector
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Naive Bayes
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Decision Tree
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Random Forests
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   1-layer NN
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   2-layer NN
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   3-layer NN
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_79219a92_3966_11e8_a752_985fd3c9006d"
#                  class="row_heading level0 row0" rowspan=1>
#                     Test Accuracy
#
#
#
#                 <td id="T_79219a92_3966_11e8_a752_985fd3c9006drow0_col0"
#                  class="data row0 col0" >
#                     0.699
#
#
#
#                 <td id="T_79219a92_3966_11e8_a752_985fd3c9006drow0_col1"
#                  class="data row0 col1" >
#                     0.747
#
#
#
#                 <td id="T_79219a92_3966_11e8_a752_985fd3c9006drow0_col2"
#                  class="data row0 col2" >
#                     0.634
#
#
#
#                 <td id="T_79219a92_3966_11e8_a752_985fd3c9006drow0_col3"
#                  class="data row0 col3" >
#                     0.661
#
#
#
#                 <td id="T_79219a92_3966_11e8_a752_985fd3c9006drow0_col4"
#                  class="data row0 col4" >
#                     0.586
#
#
#
#                 <td id="T_79219a92_3966_11e8_a752_985fd3c9006drow0_col5"
#                  class="data row0 col5" >
#                     0.747
#
#
#
#                 <td id="T_79219a92_3966_11e8_a752_985fd3c9006drow0_col6"
#                  class="data row0 col6" >
#                     0.737
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ### Ionosphere Radar Returns

# %% [markdown]
# Classification of radar returns from the ionosphere

# %%
timer.start()
X, y = UCI_Dataset_Loader.ionosphere() # <-- change this line for different experiments
scores = compute_test_accuracies(X,y, verbose=1)
timer.end_and_md_print()
print_best(scores)
pd.DataFrame(scores, columns=names, index=['Test Accuracy']).style.apply(highlight_max,axis=1)
# Out:
# Training set size: (280, 34), Test set size: (71, 34), \# of classes: 2
# Time needed to run experiment: 4.164 s
# Best classifier: **3-layer NN**
#         <style  type="text/css" >
#
#
#             #T_7bb2fc86_3966_11e8_87ad_985fd3c9006drow0_col6 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#         </style>
#
#         <table id="T_7bb2fc86_3966_11e8_87ad_985fd3c9006d" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Support Vector
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Naive Bayes
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Decision Tree
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Random Forests
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   1-layer NN
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   2-layer NN
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   3-layer NN
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_7bb2fc86_3966_11e8_87ad_985fd3c9006d"
#                  class="row_heading level0 row0" rowspan=1>
#                     Test Accuracy
#
#
#
#                 <td id="T_7bb2fc86_3966_11e8_87ad_985fd3c9006drow0_col0"
#                  class="data row0 col0" >
#                     0.897
#
#
#
#                 <td id="T_7bb2fc86_3966_11e8_87ad_985fd3c9006drow0_col1"
#                  class="data row0 col1" >
#                     0.864
#
#
#
#                 <td id="T_7bb2fc86_3966_11e8_87ad_985fd3c9006drow0_col2"
#                  class="data row0 col2" >
#                     0.869
#
#
#
#                 <td id="T_7bb2fc86_3966_11e8_87ad_985fd3c9006drow0_col3"
#                  class="data row0 col3" >
#                     0.906
#
#
#
#                 <td id="T_7bb2fc86_3966_11e8_87ad_985fd3c9006drow0_col4"
#                  class="data row0 col4" >
#                     0.897
#
#
#
#                 <td id="T_7bb2fc86_3966_11e8_87ad_985fd3c9006drow0_col5"
#                  class="data row0 col5" >
#                     0.911
#
#
#
#                 <td id="T_7bb2fc86_3966_11e8_87ad_985fd3c9006drow0_col6"
#                  class="data row0 col6" >
#                     0.925
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ### Mice Protein Expression

# %% [markdown]
# The data set consists of the expression levels of 77 proteins/protein modifications that produced detectable signals in the nuclear fraction of cortex. There are 38 control mice and 34 trisomic mice (Down syndrome), for a total of 72 mice.

# %%
timer.start()
X, y = UCI_Dataset_Loader.mice_protein() # <-- change this line for different experiments
scores = compute_test_accuracies(X,y, verbose=1)
timer.end_and_md_print()
print_best(scores)
pd.DataFrame(scores, columns=names, index=['Test Accuracy']).style.apply(highlight_max,axis=1)
# Out:
# Training set size: (864, 77), Test set size: (216, 77), \# of classes: 8
# Time needed to run experiment: 15.947 s
# Best classifier: **3-layer NN**
#         <style  type="text/css" >
#
#
#             #T_8549f894_3966_11e8_9a9f_985fd3c9006drow0_col6 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#         </style>
#
#         <table id="T_8549f894_3966_11e8_9a9f_985fd3c9006d" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Support Vector
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Naive Bayes
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Decision Tree
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Random Forests
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   1-layer NN
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   2-layer NN
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   3-layer NN
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_8549f894_3966_11e8_9a9f_985fd3c9006d"
#                  class="row_heading level0 row0" rowspan=1>
#                     Test Accuracy
#
#
#
#                 <td id="T_8549f894_3966_11e8_9a9f_985fd3c9006drow0_col0"
#                  class="data row0 col0" >
#                     0.696
#
#
#
#                 <td id="T_8549f894_3966_11e8_9a9f_985fd3c9006drow0_col1"
#                  class="data row0 col1" >
#                     0.79
#
#
#
#                 <td id="T_8549f894_3966_11e8_9a9f_985fd3c9006drow0_col2"
#                  class="data row0 col2" >
#                     0.818
#
#
#
#                 <td id="T_8549f894_3966_11e8_9a9f_985fd3c9006drow0_col3"
#                  class="data row0 col3" >
#                     0.937
#
#
#
#                 <td id="T_8549f894_3966_11e8_9a9f_985fd3c9006drow0_col4"
#                  class="data row0 col4" >
#                     0.963
#
#
#
#                 <td id="T_8549f894_3966_11e8_9a9f_985fd3c9006drow0_col5"
#                  class="data row0 col5" >
#                     0.952
#
#
#
#                 <td id="T_8549f894_3966_11e8_9a9f_985fd3c9006drow0_col6"
#                  class="data row0 col6" >
#                     0.968
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ### Nursery Admittance

# %% [markdown]
# Nursery Database was derived from a hierarchical decision model originally developed to rank applications for nursery schools. It was used during several years in 1980's when there was excessive enrollment to these schools in Ljubljana, Slovenia, and the rejected applications frequently needed an objective explanation. The final decision depended on three subproblems: occupation of parents and child's nursery, family structure and financial standing, and social and health picture of the family.

# %%
timer.start()
X, y = UCI_Dataset_Loader.nursery() # <-- change this line for different experiments
scores = compute_test_accuracies(X,y, verbose=1)
timer.end_and_md_print()
print_best(scores)
pd.DataFrame(scores, columns=names, index=['Test Accuracy']).style.apply(highlight_max,axis=1)
# Out:
# Training set size: (10367, 27), Test set size: (2592, 27), \# of classes: 5
# Time needed to run experiment: 49.664 s
# Best classifier: **1-layer NN, 2-layer NN, 3-layer NN**
#         <style  type="text/css" >
#
#
#             #T_a2f9dbcc_3966_11e8_88da_985fd3c9006drow0_col4 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_a2f9dbcc_3966_11e8_88da_985fd3c9006drow0_col5 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_a2f9dbcc_3966_11e8_88da_985fd3c9006drow0_col6 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#         </style>
#
#         <table id="T_a2f9dbcc_3966_11e8_88da_985fd3c9006d" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Support Vector
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Naive Bayes
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Decision Tree
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Random Forests
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   1-layer NN
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   2-layer NN
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   3-layer NN
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_a2f9dbcc_3966_11e8_88da_985fd3c9006d"
#                  class="row_heading level0 row0" rowspan=1>
#                     Test Accuracy
#
#
#
#                 <td id="T_a2f9dbcc_3966_11e8_88da_985fd3c9006drow0_col0"
#                  class="data row0 col0" >
#                     0.972
#
#
#
#                 <td id="T_a2f9dbcc_3966_11e8_88da_985fd3c9006drow0_col1"
#                  class="data row0 col1" >
#                     0.836
#
#
#
#                 <td id="T_a2f9dbcc_3966_11e8_88da_985fd3c9006drow0_col2"
#                  class="data row0 col2" >
#                     0.996
#
#
#
#                 <td id="T_a2f9dbcc_3966_11e8_88da_985fd3c9006drow0_col3"
#                  class="data row0 col3" >
#                     0.983
#
#
#
#                 <td id="T_a2f9dbcc_3966_11e8_88da_985fd3c9006drow0_col4"
#                  class="data row0 col4" >
#                     1
#
#
#
#                 <td id="T_a2f9dbcc_3966_11e8_88da_985fd3c9006drow0_col5"
#                  class="data row0 col5" >
#                     1
#
#
#
#                 <td id="T_a2f9dbcc_3966_11e8_88da_985fd3c9006drow0_col6"
#                  class="data row0 col6" >
#                     1
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ### Seed Classification

# %% [markdown]
# The examined group comprised kernels belonging to three different varieties of wheat: Kama, Rosa and Canadian, 70 elements each, randomly selected for
# the experiment. High quality visualization of the internal kernel structure was detected using a soft X-ray technique. It is non-destructive and considerably cheaper than other more sophisticated imaging techniques like scanning microscopy or laser technology. The images were recorded on 13x18 cm X-ray KODAK plates. Studies were conducted using combine harvested wheat grain originating from experimental fields, explored at the Institute of Agrophysics of the Polish Academy of Sciences in Lublin.

# %%
timer.start()
X, y = UCI_Dataset_Loader.seeds() # <-- change this line for different experiments
scores = compute_test_accuracies(X,y, verbose=1)
timer.end_and_md_print()
print_best(scores)
pd.DataFrame(scores, columns=names, index=['Test Accuracy']).style.apply(highlight_max,axis=1)
# Out:
# Training set size: (167, 7), Test set size: (42, 7), \# of classes: 3
# Time needed to run experiment: 0.853 s
# Best classifier: **Support Vector, Naive Bayes, Random Forests**
#         <style  type="text/css" >
#
#
#             #T_a3949ea6_3966_11e8_a36c_985fd3c9006drow0_col0 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_a3949ea6_3966_11e8_a36c_985fd3c9006drow0_col1 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_a3949ea6_3966_11e8_a36c_985fd3c9006drow0_col3 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#         </style>
#
#         <table id="T_a3949ea6_3966_11e8_a36c_985fd3c9006d" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Support Vector
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Naive Bayes
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Decision Tree
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Random Forests
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   1-layer NN
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   2-layer NN
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   3-layer NN
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_a3949ea6_3966_11e8_a36c_985fd3c9006d"
#                  class="row_heading level0 row0" rowspan=1>
#                     Test Accuracy
#
#
#
#                 <td id="T_a3949ea6_3966_11e8_a36c_985fd3c9006drow0_col0"
#                  class="data row0 col0" >
#                     0.929
#
#
#
#                 <td id="T_a3949ea6_3966_11e8_a36c_985fd3c9006drow0_col1"
#                  class="data row0 col1" >
#                     0.929
#
#
#
#                 <td id="T_a3949ea6_3966_11e8_a36c_985fd3c9006drow0_col2"
#                  class="data row0 col2" >
#                     0.905
#
#
#
#                 <td id="T_a3949ea6_3966_11e8_a36c_985fd3c9006drow0_col3"
#                  class="data row0 col3" >
#                     0.929
#
#
#
#                 <td id="T_a3949ea6_3966_11e8_a36c_985fd3c9006drow0_col4"
#                  class="data row0 col4" >
#                     0.421
#
#
#
#                 <td id="T_a3949ea6_3966_11e8_a36c_985fd3c9006drow0_col5"
#                  class="data row0 col5" >
#                     0.278
#
#
#
#                 <td id="T_a3949ea6_3966_11e8_a36c_985fd3c9006drow0_col6"
#                  class="data row0 col6" >
#                     0.603
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ### Seismic Mining

# %% [markdown]
# Mining activity was and is always connected with the occurrence of dangers which are commonly called
# mining hazards. In this case, the goal is to predict hazardous seismic activity

# %%
timer.start()
X, y = UCI_Dataset_Loader.seismic() # <-- change this line for different experiments
scores = compute_test_accuracies(X,y, verbose=1)
timer.end_and_md_print()
print_best(scores)
pd.DataFrame(scores, columns=names, index=['Test Accuracy']).style.apply(highlight_max,axis=1)
# Out:
# Training set size: (2066, 24), Test set size: (517, 24), \# of classes: 2
# Time needed to run experiment: 3.042 s
# Best classifier: **Support Vector**
#         <style  type="text/css" >
#
#
#             #T_a57bc252_3966_11e8_a796_985fd3c9006drow0_col0 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#         </style>
#
#         <table id="T_a57bc252_3966_11e8_a796_985fd3c9006d" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Support Vector
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Naive Bayes
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Decision Tree
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Random Forests
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   1-layer NN
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   2-layer NN
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   3-layer NN
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_a57bc252_3966_11e8_a796_985fd3c9006d"
#                  class="row_heading level0 row0" rowspan=1>
#                     Test Accuracy
#
#
#
#                 <td id="T_a57bc252_3966_11e8_a796_985fd3c9006drow0_col0"
#                  class="data row0 col0" >
#                     0.942
#
#
#
#                 <td id="T_a57bc252_3966_11e8_a796_985fd3c9006drow0_col1"
#                  class="data row0 col1" >
#                     0.911
#
#
#
#                 <td id="T_a57bc252_3966_11e8_a796_985fd3c9006drow0_col2"
#                  class="data row0 col2" >
#                     0.885
#
#
#
#                 <td id="T_a57bc252_3966_11e8_a796_985fd3c9006drow0_col3"
#                  class="data row0 col3" >
#                     0.937
#
#
#
#                 <td id="T_a57bc252_3966_11e8_a796_985fd3c9006drow0_col4"
#                  class="data row0 col4" >
#                     0.663
#
#
#
#                 <td id="T_a57bc252_3966_11e8_a796_985fd3c9006drow0_col5"
#                  class="data row0 col5" >
#                     0.734
#
#
#
#                 <td id="T_a57bc252_3966_11e8_a796_985fd3c9006drow0_col6"
#                  class="data row0 col6" >
#                     0.471
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ### Soybean

# %% [markdown]
# "Learning by being told and learning from examples: an experimental comparison of the two methodes of knowledge acquisition in the context of developing an expert system for soybean desease diagnoiss"

# %%
timer.start()
X, y = UCI_Dataset_Loader.soybean() # <-- change this line for different experiments
scores = compute_test_accuracies(X,y, verbose=1)
timer.end_and_md_print()
print_best(scores)
pd.DataFrame(scores, columns=names, index=['Test Accuracy']).style.apply(highlight_max,axis=1)
# Out:
# Training set size: (36, 35), Test set size: (10, 35), \# of classes: 4
# Time needed to run experiment: 1.271 s
# Best classifier: **Support Vector, Naive Bayes, Decision Tree, Random Forests, 1-layer NN, 2-layer NN, 3-layer NN**
#         <style  type="text/css" >
#
#
#             #T_a6530f94_3966_11e8_ac0c_985fd3c9006drow0_col0 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_a6530f94_3966_11e8_ac0c_985fd3c9006drow0_col1 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_a6530f94_3966_11e8_ac0c_985fd3c9006drow0_col2 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_a6530f94_3966_11e8_ac0c_985fd3c9006drow0_col3 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_a6530f94_3966_11e8_ac0c_985fd3c9006drow0_col4 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_a6530f94_3966_11e8_ac0c_985fd3c9006drow0_col5 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_a6530f94_3966_11e8_ac0c_985fd3c9006drow0_col6 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#         </style>
#
#         <table id="T_a6530f94_3966_11e8_ac0c_985fd3c9006d" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Support Vector
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Naive Bayes
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Decision Tree
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Random Forests
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   1-layer NN
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   2-layer NN
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   3-layer NN
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_a6530f94_3966_11e8_ac0c_985fd3c9006d"
#                  class="row_heading level0 row0" rowspan=1>
#                     Test Accuracy
#
#
#
#                 <td id="T_a6530f94_3966_11e8_ac0c_985fd3c9006drow0_col0"
#                  class="data row0 col0" >
#                     1
#
#
#
#                 <td id="T_a6530f94_3966_11e8_ac0c_985fd3c9006drow0_col1"
#                  class="data row0 col1" >
#                     1
#
#
#
#                 <td id="T_a6530f94_3966_11e8_ac0c_985fd3c9006drow0_col2"
#                  class="data row0 col2" >
#                     1
#
#
#
#                 <td id="T_a6530f94_3966_11e8_ac0c_985fd3c9006drow0_col3"
#                  class="data row0 col3" >
#                     1
#
#
#
#                 <td id="T_a6530f94_3966_11e8_ac0c_985fd3c9006drow0_col4"
#                  class="data row0 col4" >
#                     1
#
#
#
#                 <td id="T_a6530f94_3966_11e8_ac0c_985fd3c9006drow0_col5"
#                  class="data row0 col5" >
#                     1
#
#
#
#                 <td id="T_a6530f94_3966_11e8_ac0c_985fd3c9006drow0_col6"
#                  class="data row0 col6" >
#                     1
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ### Teaching Assistant Evaluation

# %% [markdown]
# The data consist of evaluations of teaching performance over three regular semesters and two summer semesters of 151 teaching assistant (TA) assignments at the Statistics Department of the University of Wisconsin-Madison. The scores were divided into 3 roughly equal-sized categories ("low", "medium", and "high") to form the class variable.

# %%
timer.start()
X, y = UCI_Dataset_Loader.teaching_assistant() # <-- change this line for different experiments
scores = compute_test_accuracies(X,y, verbose=1)
timer.end_and_md_print()
print_best(scores)
pd.DataFrame(scores, columns=names, index=['Test Accuracy']).style.apply(highlight_max,axis=1)
# Out:
# Training set size: (120, 5), Test set size: (30, 5), \# of classes: 3
# Time needed to run experiment: 0.47 s
# Best classifier: **Decision Tree**
#         <style  type="text/css" >
#
#
#             #T_a6b0fe8c_3966_11e8_8ea4_985fd3c9006drow0_col2 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#         </style>
#
#         <table id="T_a6b0fe8c_3966_11e8_8ea4_985fd3c9006d" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Support Vector
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Naive Bayes
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Decision Tree
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Random Forests
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   1-layer NN
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   2-layer NN
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   3-layer NN
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_a6b0fe8c_3966_11e8_8ea4_985fd3c9006d"
#                  class="row_heading level0 row0" rowspan=1>
#                     Test Accuracy
#
#
#
#                 <td id="T_a6b0fe8c_3966_11e8_8ea4_985fd3c9006drow0_col0"
#                  class="data row0 col0" >
#                     0.422
#
#
#
#                 <td id="T_a6b0fe8c_3966_11e8_8ea4_985fd3c9006drow0_col1"
#                  class="data row0 col1" >
#                     0.533
#
#
#
#                 <td id="T_a6b0fe8c_3966_11e8_8ea4_985fd3c9006drow0_col2"
#                  class="data row0 col2" >
#                     0.556
#
#
#
#                 <td id="T_a6b0fe8c_3966_11e8_8ea4_985fd3c9006drow0_col3"
#                  class="data row0 col3" >
#                     0.533
#
#
#
#                 <td id="T_a6b0fe8c_3966_11e8_8ea4_985fd3c9006drow0_col4"
#                  class="data row0 col4" >
#                     0.344
#
#
#
#                 <td id="T_a6b0fe8c_3966_11e8_8ea4_985fd3c9006drow0_col5"
#                  class="data row0 col5" >
#                     0.4
#
#
#
#                 <td id="T_a6b0fe8c_3966_11e8_8ea4_985fd3c9006drow0_col6"
#                  class="data row0 col6" >
#                     0.3
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ### Tic Tac Toe Endgame

# %% [markdown]
# This database encodes the complete set of possible board configurations at the end of tic-tac-toe games, where "x" is assumed to have played first. The target concept is "win for x" (i.e., true when "x" has one of 8 possible ways to create a "three-in-a-row").

# %%
timer.start()
X, y = UCI_Dataset_Loader.tic_tac_toe() # <-- change this line for different experiments
scores = compute_test_accuracies(X,y, verbose=1)
timer.end_and_md_print()
print_best(scores)
pd.DataFrame(scores, columns=names, index=['Test Accuracy']).style.apply(highlight_max,axis=1)
# Out:
# Training set size: (765, 27), Test set size: (192, 27), \# of classes: 2
# Time needed to run experiment: 7.827 s
# Best classifier: **2-layer NN**
#         <style  type="text/css" >
#
#
#             #T_ab70611a_3966_11e8_80eb_985fd3c9006drow0_col5 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#         </style>
#
#         <table id="T_ab70611a_3966_11e8_80eb_985fd3c9006d" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Support Vector
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Naive Bayes
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Decision Tree
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Random Forests
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   1-layer NN
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   2-layer NN
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   3-layer NN
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_ab70611a_3966_11e8_80eb_985fd3c9006d"
#                  class="row_heading level0 row0" rowspan=1>
#                     Test Accuracy
#
#
#
#                 <td id="T_ab70611a_3966_11e8_80eb_985fd3c9006drow0_col0"
#                  class="data row0 col0" >
#                     0.852
#
#
#
#                 <td id="T_ab70611a_3966_11e8_80eb_985fd3c9006drow0_col1"
#                  class="data row0 col1" >
#                     0.639
#
#
#
#                 <td id="T_ab70611a_3966_11e8_80eb_985fd3c9006drow0_col2"
#                  class="data row0 col2" >
#                     0.938
#
#
#
#                 <td id="T_ab70611a_3966_11e8_80eb_985fd3c9006drow0_col3"
#                  class="data row0 col3" >
#                     0.951
#
#
#
#                 <td id="T_ab70611a_3966_11e8_80eb_985fd3c9006drow0_col4"
#                  class="data row0 col4" >
#                     0.976
#
#
#
#                 <td id="T_ab70611a_3966_11e8_80eb_985fd3c9006drow0_col5"
#                  class="data row0 col5" >
#                     0.979
#
#
#
#                 <td id="T_ab70611a_3966_11e8_80eb_985fd3c9006drow0_col6"
#                  class="data row0 col6" >
#                     0.967
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ### Website Phishing

# %% [markdown]
# We have identified different features related to legitimate and phishy websites and collected 1353 different websites from difference sources.Phishing websites were collected from Phishtank data archive, which is a free community site where users can submit, verify, track and share phishing data.

# %%
timer.start()
X, y = UCI_Dataset_Loader.website_phishing() # <-- change this line for different experiments
scores = compute_test_accuracies(X,y, verbose=1)
timer.end_and_md_print()
print_best(scores)
pd.DataFrame(scores, columns=names, index=['Test Accuracy']).style.apply(highlight_max,axis=1)
# Out:
# Training set size: (1082, 9), Test set size: (271, 9), \# of classes: 3
# Time needed to run experiment: 11.575 s
# Best classifier: **2-layer NN**
#         <style  type="text/css" >
#
#
#             #T_b270a7a2_3966_11e8_bb6b_985fd3c9006drow0_col5 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#         </style>
#
#         <table id="T_b270a7a2_3966_11e8_bb6b_985fd3c9006d" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Support Vector
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Naive Bayes
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Decision Tree
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Random Forests
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   1-layer NN
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   2-layer NN
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   3-layer NN
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_b270a7a2_3966_11e8_bb6b_985fd3c9006d"
#                  class="row_heading level0 row0" rowspan=1>
#                     Test Accuracy
#
#
#
#                 <td id="T_b270a7a2_3966_11e8_bb6b_985fd3c9006drow0_col0"
#                  class="data row0 col0" >
#                     0.866
#
#
#
#                 <td id="T_b270a7a2_3966_11e8_bb6b_985fd3c9006drow0_col1"
#                  class="data row0 col1" >
#                     0.838
#
#
#
#                 <td id="T_b270a7a2_3966_11e8_bb6b_985fd3c9006drow0_col2"
#                  class="data row0 col2" >
#                     0.893
#
#
#
#                 <td id="T_b270a7a2_3966_11e8_bb6b_985fd3c9006drow0_col3"
#                  class="data row0 col3" >
#                     0.895
#
#
#
#                 <td id="T_b270a7a2_3966_11e8_bb6b_985fd3c9006drow0_col4"
#                  class="data row0 col4" >
#                     0.889
#
#
#
#                 <td id="T_b270a7a2_3966_11e8_bb6b_985fd3c9006drow0_col5"
#                  class="data row0 col5" >
#                     0.904
#
#
#
#                 <td id="T_b270a7a2_3966_11e8_bb6b_985fd3c9006drow0_col6"
#                  class="data row0 col6" >
#                     0.893
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ### Wholesale Customer Region

# %% [markdown]
# The data set refers to clients of a wholesale distributor. It includes the annual spending in monetary units (m.u.) on diverse product categories. Can we predict what region/country a customer is from based on how they spend?

# %%
timer.start()
X, y = UCI_Dataset_Loader.wholesale_customers() # <-- change this line for different experiments
scores = compute_test_accuracies(X,y, verbose=1)
timer.end_and_md_print()
print_best(scores)
pd.DataFrame(scores, columns=names, index=['Test Accuracy']).style.apply(highlight_max,axis=1)
# Out:
# Training set size: (352, 6), Test set size: (88, 6), \# of classes: 3
# Time needed to run experiment: 0.527 s
# Best classifier: **Support Vector**
#         <style  type="text/css" >
#
#
#             #T_b2d7db08_3966_11e8_8900_985fd3c9006drow0_col0 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#         </style>
#
#         <table id="T_b2d7db08_3966_11e8_8900_985fd3c9006d" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Support Vector
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Naive Bayes
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Decision Tree
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Random Forests
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   1-layer NN
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   2-layer NN
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   3-layer NN
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_b2d7db08_3966_11e8_8900_985fd3c9006d"
#                  class="row_heading level0 row0" rowspan=1>
#                     Test Accuracy
#
#
#
#                 <td id="T_b2d7db08_3966_11e8_8900_985fd3c9006drow0_col0"
#                  class="data row0 col0" >
#                     0.758
#
#
#
#                 <td id="T_b2d7db08_3966_11e8_8900_985fd3c9006drow0_col1"
#                  class="data row0 col1" >
#                     0.485
#
#
#
#                 <td id="T_b2d7db08_3966_11e8_8900_985fd3c9006drow0_col2"
#                  class="data row0 col2" >
#                     0.542
#
#
#
#                 <td id="T_b2d7db08_3966_11e8_8900_985fd3c9006drow0_col3"
#                  class="data row0 col3" >
#                     0.682
#
#
#
#                 <td id="T_b2d7db08_3966_11e8_8900_985fd3c9006drow0_col4"
#                  class="data row0 col4" >
#                     0.5
#
#
#
#                 <td id="T_b2d7db08_3966_11e8_8900_985fd3c9006drow0_col5"
#                  class="data row0 col5" >
#                     0.655
#
#
#
#                 <td id="T_b2d7db08_3966_11e8_8900_985fd3c9006drow0_col6"
#                  class="data row0 col6" >
#                     0.61
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# # Conclusions

# %% [markdown]
# ### Aggregated Results

# %%
all_data_df = pd.DataFrame(np.array(all_data).squeeze())
all_data_df.columns = ['# of Points','Dimensionality','# of Classes'] + names
all_data_df.style.apply(highlight_max_excluding_first_three,axis=1)
# Out:
#         <style  type="text/css" >
#
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow0_col6 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow1_col8 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow2_col6 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow4_col7 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow5_col9 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow6_col6 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow7_col4 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow7_col8 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow8_col9 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow9_col9 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow10_col7 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow10_col8 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow10_col9 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow11_col4 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow11_col6 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow13_col4 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow13_col5 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow13_col6 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow13_col7 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow13_col8 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow13_col9 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow14_col5 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow15_col8 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_41b68d38_39ae_11e8_8922_985fd3c9006drow16_col8 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#         </style>
#
#         <table id="T_41b68d38_39ae_11e8_8922_985fd3c9006d" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   # of Points
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Dimensionality
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   # of Classes
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Support Vector
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   Naive Bayes
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   Decision Tree
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   Random Forests
#
#
#
#                 <th class="col_heading level0 col7" colspan=1>
#                   1-layer NN
#
#
#
#                 <th class="col_heading level0 col8" colspan=1>
#                   2-layer NN
#
#
#
#                 <th class="col_heading level0 col9" colspan=1>
#                   3-layer NN
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_41b68d38_39ae_11e8_8922_985fd3c9006d"
#                  class="row_heading level0 row0" rowspan=1>
#                     0
#
#
#
#                 <td id="T_41b68d38_39ae_11e8_8922_985fd3c9006drow0_col0"
#                  class="data row0 col0" >
#                     3.26e+04
#
#
#
#                 <td id="T_41b68d38_39ae_11e8_8922_985fd3c9006drow0_col1"
#                  class="data row0 col1" >
#                     108
#
#
#
#                 <td id="T_41b68d38_39ae_11e8_8922_985fd3c9006drow0_col2"
#                  class="data row0 col2" >
#                     2
#
#
#
#                 <td id="T_41b68d38_39ae_11e8_8922_985fd3c9006drow0_col3"
#                  class="data row0 col3" >
#                     0.753
#
#
#
#                 <td id="T_41b68d38_39ae_11e8_8922_985fd3c9006drow0_col4"
#                  class="data row0 col4" >
#                     0.799
#
#
#
#                 <td id="T_41b68d38_39ae_11e8_8922_985fd3c9006drow0_col5"
#                  class="data row0 col5" >
#                     0.817
#
#
#
#                 <td id="T_41b68d38_39ae_11e8_8922_985fd3c9006drow0_col6"
#                  class="data row0 col6" >
#                     0.847
#
#
#
#                 <td id="T_41b68d38_39ae_11e8_8922_985fd3c9006drow0_col7"
#                  class="data row0 col7" >
#                     0.605
#
#
#
#                 <td id="T_41b68d38_39ae_11e8_8922_985fd3c9006drow0_col8"
#                  class="data row0 col8" >
#                     0.599
#
#
#
#                 <td id="T_41b68d38_39ae_11e8_8922_985fd3c9006drow0_col9"
#                  class="data row0 col9" >
#                     0.784
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_41b68d38_39ae_11e8_8922_985fd3c9006d"
#                  class="row_heading level0 row1" rowspan=1>
#                     1

# %% [markdown]
# ### Mean Accuracy and Rank

# %%
df_mean = all_data_df.mean(axis=0)[3:].to_frame()
df_mean.columns = ['Average Accuracy']

df_rank = all_data_df.iloc[:,3:].rank(method="min", axis=1, ascending=True).mean(axis=0).to_frame()
df_rank.columns = ['Average Rank (higher better)']

df = pd.concat([df_mean, df_rank], axis=1)
df.style.apply(highlight_max)
# Out:
#         <style  type="text/css" >
#
#
#             #T_b30bf708_3966_11e8_927f_985fd3c9006drow3_col0 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#             #T_b30bf708_3966_11e8_927f_985fd3c9006drow3_col1 {
#
#                 background-color:  #5fba7d;
#
#             }
#
#         </style>
#
#         <table id="T_b30bf708_3966_11e8_927f_985fd3c9006d" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Average Accuracy
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Average Rank (higher better)
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_b30bf708_3966_11e8_927f_985fd3c9006d"
#                  class="row_heading level0 row0" rowspan=1>
#                     Support Vector
#
#
#
#                 <td id="T_b30bf708_3966_11e8_927f_985fd3c9006drow0_col0"
#                  class="data row0 col0" >
#                     0.774
#
#
#
#                 <td id="T_b30bf708_3966_11e8_927f_985fd3c9006drow0_col1"
#                  class="data row0 col1" >
#                     3.5
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_b30bf708_3966_11e8_927f_985fd3c9006d"
#                  class="row_heading level0 row1" rowspan=1>
#                     Naive Bayes
#
#
#
#                 <td id="T_b30bf708_3966_11e8_927f_985fd3c9006drow1_col0"
#                  class="data row1 col0" >
#                     0.699
#
#
#
#                 <td id="T_b30bf708_3966_11e8_927f_985fd3c9006drow1_col1"
#                  class="data row1 col1" >
#                     2.39
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_b30bf708_3966_11e8_927f_985fd3c9006d"
#                  class="row_heading level0 row2" rowspan=1>
#                     Decision Tree
#
#
#
#                 <td id="T_b30bf708_3966_11e8_927f_985fd3c9006drow2_col0"
#                  class="data row2 col0" >
#                     0.798
#
#
#
#                 <td id="T_b30bf708_3966_11e8_927f_985fd3c9006drow2_col1"
#                  class="data row2 col1" >
#                     3.94
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_b30bf708_3966_11e8_927f_985fd3c9006d"
#                  class="row_heading level0 row3" rowspan=1>
#                     Random Forests
#
#
#
#                 <td id="T_b30bf708_3966_11e8_927f_985fd3c9006drow3_col0"
#                  class="data row3 col0" >
#                     0.828
#
#
#
#                 <td id="T_b30bf708_3966_11e8_927f_985fd3c9006drow3_col1"
#                  class="data row3 col1" >
#                     4.78
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_b30bf708_3966_11e8_927f_985fd3c9006d"
#                  class="row_heading level0 row4" rowspan=1>
#                     1-layer NN
#
#
#
#                 <td id="T_b30bf708_3966_11e8_927f_985fd3c9006drow4_col0"
#                  class="data row4 col0" >
#                     0.721
#
#
#
#                 <td id="T_b30bf708_3966_11e8_927f_985fd3c9006drow4_col1"
#                  class="data row4 col1" >
#                     3.22
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_b30bf708_3966_11e8_927f_985fd3c9006d"
#                  class="row_heading level0 row5" rowspan=1>
#                     2-layer NN
#
#
#
#                 <td id="T_b30bf708_3966_11e8_927f_985fd3c9006drow5_col0"
#                  class="data row5 col0" >
#                     0.742
#
#
#
#                 <td id="T_b30bf708_3966_11e8_927f_985fd3c9006drow5_col1"
#                  class="data row5 col1" >
#                     4.22
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_b30bf708_3966_11e8_927f_985fd3c9006d"
#                  class="row_heading level0 row6" rowspan=1>
#                     3-layer NN
#
#
#
#                 <td id="T_b30bf708_3966_11e8_927f_985fd3c9006drow6_col0"
#                  class="data row6 col0" >
#                     0.752
#
#
#
#                 <td id="T_b30bf708_3966_11e8_927f_985fd3c9006drow6_col1"
#                  class="data row6 col1" >
#                     4.28
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# #### Overall Recommendation

# %% [markdown]
# Based on these results, if you'd like to use a machine learning off-the-shelf to classify your numerical dataset, a good choice to use is a:
#
# **Random Forest**, as it seems to work quite well on datasets of many different sizes and dimensionalities. In several datasets, 2- or 3-layer neural networks (NNs) offer some improvement to Random Forests, but for some datasets (particularly those with a small number of data points), NNs perform a lot worse, bringing down their overall accuracy. Perhaps NNs could be regularized to improve performance, but with off-the-shelf hyper-parameters, Random Forests are your best bet.
#
# In a similar manner, SVMs achieved the top accuracy on only a few datasets, but had a very respectable average accuracy, in part because they did not fail terribly on any dataset. Compare this to for example Naive Bayes, which had the top performance on a couple of small datasets, but had the worst average performance overall in part because they had very poor performance on some datasets. Naive Bayes would not seem to be a good method to use generally. Of course, all of these considerations are based only on test accuracy. if you have other considerations besides test accuracy (e.g. interpretability), then some of the simpler methods may make sense. In particular, Decision Trees (though rarely a top performer) had quite good overall average accuracy and may be a good choice if interpretability is a key concern.

# %% [markdown]
# ** _If this notebook was helpful in your research, please cite it using bibtex entry below:_ **
#
# ```
# @misc{abid2018atomic,
#   title={Which Machine Learning Classifier Is the Best on 18 UCI Datasets?},
#   author={Abid, Abubakar},
#   year={2018},
#   publisher={GitHub},
#   howpublished={\url{https://github.com/abidlabs/AtomsOfDeepLearning}},
# }
# ```
